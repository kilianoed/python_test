# %% [markdown]
# # Chapter 1

# %%
# schreibe 5 variablen mit unterschiedlichen Datentypen

# %%
a = 4

# %%
b = 5.2

# %%
c = 3+0j

# %%
d = "Text"

# %%
e = (3, 'socialism')

# %%
f = 3.7

# %%
g = 5

# %%
z = "Beispiel"

# %%
y = ["das", "ist"]
x = ["ein Beispiel"]

# %%
# Addiere zwei Variablen mit jeweils gleichen Datentypen

# %%
g+a
# Out:
# 9

# %%
b+f
# Out:
# 8.9

# %%
d + z
# Out:
# 'TextBeispiel'

# %%
y + x
# Out:
# ['das', 'ist', 'ein Beispiel']

# %%
# Subtrahiere zwei Variablen mit jeweils gleichen Datentypen

# %%
g-a
# Out:
# 1

# %%
b-f
# Out:
# 1.5

# %%
# Schreibe eine Liste und nimm das 2. und 4. Element der Liste, sowie das 2.-4.

# %%
h = [a, b, c, d, f]

# %%
print (h)
# Out:
# [4, 5.2, (3+0j), 'Text', 3.7]

# %%
print(h[1],h[3])
# Out:
# 5.2 Text

# %%
print(h[1:4])
# Out:
# [5.2, (3+0j), 'Text']

# %%
h[2:4] = [2,3,4]
print(h)
# Out:
# [4, 5.2, 2, 3, 4, 3.7]

# %%
# Verändere einen String

# %%
z[0] = "D"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 z[0] = "D"
#
# TypeError: 'str' object does not support item assignment

# %%
## Veränderte Ausgabe

# %%
d.upper()

# %%
## Veränderte Variable

# %%
d = "key"

# %%
print(d)

# %%
# Verändere (verlängere) eine Liste

# %%
h.append(42)

# %%
print(h)

# %%
# Verändere (verlängere) ein Tupel

# %%
k = ('one', 2.0, 3, 'four')

# %%
l = list(k)

# %%
l.append(5.0)

# %%
k = tuple(l)

# %%
print (k)

# %% [markdown]
# # Chapter 2

# %%
# Iteriere über eine Liste und gebe jedes Element aus

# %%
a = ['one', 3, 4, 0.5, 'water', (5, 'text')]

# %%
for x in a:
    print(x)

# %%
# Iteriere über eine Liste und gebe nur Elemente aus die type String sind

# %%
for element in a:
    if type(element) == str:
        print(element)

# %%
# Iteriere über ein Tupel und gebe jedes Element aus

# %%
b = (5, 3.4, 'hello', 65, (4, 5))

# %%
for x in b:
    print(x)

# %%
# Iteriere über ein Tupel und gebe jedes Element sowie dessen Index aus

# %%
for element in b:
    print(element, "is no.",b.index(element))

# %%
for i, element in enumerate(b):
    print(i, element)

# %%
# Iteriere über die keys in einem dictionary

# %%
c = {
    "model": "NX-6",
    "incept date": "2015",
    "serial number": "NX6-409230RB",
    "name": "roy"
}

# %%
for key in c:
    print(key)

# %%
# Iteriere über eine Liste und gebe ein anderes Feedback für jeden Datentyp
# (mindestens drei unterschiedliche Datentypen)

# %%
print(a)
a.append(["i"])
print(a)

# %%
for element in a:
    if type(element) == str:
        print("This is a string");
    elif type(element) == int:
        print("This is an integer");
    elif type(element) == float:
        print("This is a float");
    elif type(element) == tuple:
        print("This is a tuple")
    else:
        print("Type not found")

# %%
# Iteriere über einen String

# %%
d = 'this is a string'

# %%
for element in d:
    print(element)

# %%
# Iteriere über zwei Listen gleichzeitig

# %%
e = list(b)

# %%
for x, y in zip(a, e):
    print(x, "and", y)

# %% [markdown]
# # Chapter 3

# %%
# funktionen
def add_items(a, b):
    c = a + b
    return c

# %%
add_items(1, 2)

# %%
def add_items_short(a, b):
    e = 5
    b = b + e
    return a + b

# %%
add_items_short(1, 2)

# %%
def greeting():
    print("Hi")

# %%
greeting()

# %%
# schreibe eine Funktion die eine Liste als input argument nimmt 
# und alle elemente einzeln zurückgibt

# %%
def print_list_elements(a):
    for element in a:
        print(element)

# %%
print_list_elements(a)

# %%
print_list_elements(e)

# %%
# Schreibe eine Funktion die ein integer mit 3 multipliziert - bis 10*3

# %%
def multiply_by_three (x):
    for n in range(1,11):
        print (x *3 *n)

# %%
multiply_by_three(4)

# %%
def multiply_by_x (y,x):
    for n in range(1,11):
        print (x *y *n)

# %%
multiply_by_x (8, 4)

# %%
# Schreibe eine Funktion die ein integer mit 3 multipliziert - bis 10*3
# und das Ergebnis als Liste zurück gibt

# %%
def multiply_by_three_list (x):
   return [x * 3 * n for n in range(1,11)]

# %%
new_list = multiply_by_three_list (5)
print(new_list)

# %%
# tests/fragen

# %%
def multiply_by_three_test (x):
   print(x * 3 * n for n in range(1,11))

# %%
multiply_by_three_test (2)

# %%
def multiply_by_three_list_test (x):
   print([x * n for n in range(3,31,3)])

# %%
multiply_by_three_list_test (5)

# %% [markdown]
# # Chapter 4

# %%
# Öffne eine Datei mit Python und lese den Inhalt in eine Liste

# %%
filename = "text.txt"

# %%
with open(filename, "r") as f:
   list1 = f.readlines()

# %%
print(list1)

# %%
print(list1[1])

# %%
# Schreibe eine Liste in eine Datei

# %%
c_test = ["this", "is", "a", "text", "file"]

# %%
with open("text2.txt", "w") as f:
    f.write(str(c_test))

# %%
## imports

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# plotte eine cos-Funktion

# %%
print(np.cos(10))

# %%
x = np.arange(0, 10, 0.1)
y = np.cos(x)

# %%
plt.plot(x,y)
plt.xlim([0, 10])
plt.show()

# %%
# Mache einen barplot von einer Liste

# %%
c_test = [2, 5, 9, 1, 10, 7, 8, 5, 3.6, 7, 5.1]

# %%
plt.bar(range(len(c_test)), c_test)
plt.show()

# %%
# mache einen scatterplot einer liste

# %%
plt.scatter(range(len(c_test)), c_test)
plt.show()

# %% [markdown]
# # Chapter 5

# %%
# finde datensatz auf kaggle und lese ein als csv

# %%
## datensatz aus: https://www.slavevoyages.org/voyage/database#results (1830; gefilterte columns)

# %%
slaves = pd.read_csv("slaves_1835-1839.csv", index_col=1)

# %%
slaves
# Out:
#            Year of arrival at port of disembarkation  \
# Voyage ID
# 1355                                            1835
# 1356                                            1835
# 1357                                            1835
# 1358                                            1835
# 1359                                            1835
# ...                                              ...
# 900159                                          1839
# 900160                                          1839
# 900161                                          1839
# 900163                                          1839
# 900164                                          1839
#
#                            Vessel name  \
# Voyage ID
# 1355                             Maria
# 1356                         Manuelita
# 1357                          Mariposa
# 1358                           Luisita
# 1359              Andaluz (a) Terrible
# ...                                ...
# 900159                         Nereida
# 900160                   Onze de Março
# 900161               Paquete de Luanda
# 900163     Socorro (a) D Maria Segunda
# 900164                           Veloz
#
#           Voyage itinerary imputed principal place of slave purchase (mjbyptimp)   \
# Voyage ID
# 1355                                                   Bonny
# 1356                                Africa, port unspecified
# 1357                                Africa, port unspecified
# 1358                            Gold Coast, port unspecified
# 1359                                                São Tomé
# ...                                                      ...
# 900159                                            Mozambique
# 900160     West Central Africa and St. Helena, port unspe...
# 900161     West Central Africa and St. Helena, port unspe...
# 900163                                            Mozambique
# 900164                                            Mozambique
#
#           Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  \
# Voyage ID
# 1355                                  Cuba, port unspecified
# 1356                                  Cuba, port unspecified
# 1357                                  Cuba, port unspecified
# 1358                                                  Havana
# 1359                                                  Havana
# ...                                                      ...
# 900159                                        Rio de Janeiro
# 900160                                                   NaN
# 900161                                                   NaN
# 900163                                Cuba, port unspecified
# 900164                                        Rio de Janeiro
#
#            Total embarked  Total disembarked  Captive deaths during crossing  \
# Voyage ID
# 1355                368.0              341.0                            27.0
# 1356                307.0              277.0                             NaN
# 1357                307.0              277.0                             NaN
# 1358                284.0              270.0                             NaN
# 1359                411.0              369.0                             NaN
# ...                   ...                ...                             ...
# 900159              514.0              421.0                             NaN
# 900160              490.0              444.0                             NaN
# 900161              490.0              444.0                             NaN
# 900163              514.0              421.0                             NaN
# 900164              514.0              421.0                             NaN
#
#            Duration of captives' crossing (in days)  Crew at voyage outset
# Voyage ID
# 1355                                            NaN                   24.0
# 1356                                            NaN                    NaN
# 1357                                            NaN                    NaN
# 1358                                            NaN                    NaN
# 1359                                            NaN                    NaN
# ...                                             ...                    ...
# 900159                                          NaN                    NaN
# 900160                                          NaN                    NaN
# 900161                                          NaN                    NaN
# 900163                                          NaN                    NaN
# 900164                                          NaN                    NaN
#
# [976 rows x 9 columns]

# %%
slaves.dtypes
# Out:
# Year of arrival at port of disembarkation                                              int64
# Vessel name                                                                           object
# Voyage itinerary imputed principal place of slave purchase (mjbyptimp)                object
# Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place     object
# Total embarked                                                                       float64
# Total disembarked                                                                    float64
# Captive deaths during crossing                                                       float64
# Duration of captives' crossing (in days)                                             float64
# Crew at voyage outset                                                                float64
# dtype: object

# %%
slaves.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 976 entries, 1355 to 900164
# Data columns (total 9 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Year of arrival at port of disembarkation                                          976 non-null    int64
#  1   Vessel name                                                                        957 non-null    object
#  2   Voyage itinerary imputed principal place of slave purchase (mjbyptimp)             870 non-null    object
#  3   Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  854 non-null    object
#  4   Total embarked                                                                     870 non-null    float64
#  5   Total disembarked                                                                  870 non-null    float64
#  6   Captive deaths during crossing                                                     136 non-null    float64
#  7   Duration of captives' crossing (in days)                                           185 non-null    float64
#  8   Crew at voyage outset                                                              330 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 76.2+ KB

# %%
# Stelle wichtige Kolumnen graphisch dar (pyplot)

# %%
disembarked = slaves["Total disembarked"]
plt.scatter(range(len(disembarked)), disembarked)
plt.show()

# %%
embarked = slaves["Captive deaths during crossing"]
plt.scatter(range(len(embarked)), embarked)
plt.show()

# %%
duration = slaves["Duration of captives' crossing (in days)"]
plt.scatter(range(len(duration)), duration)
plt.show()

# %%
# Stelle wichtige Korrelationen numerisch dar (corr)

# %%
slaves_num = slaves.loc[:, ~slaves.columns.isin(['Voyage ID', 'Vessel name'])]
print(slaves_num.corr(numeric_only = True))
# Out:
#                                            Year of arrival at port of disembarkation  \
# Year of arrival at port of disembarkation                                   1.000000
# Total embarked                                                              0.084994
# Total disembarked                                                           0.087017
# Captive deaths during crossing                                              0.101410
# Duration of captives' crossing (in days)                                    0.018499
# Crew at voyage outset                                                      -0.126635
#
#                                            Total embarked  Total disembarked  \
# Year of arrival at port of disembarkation        0.084994           0.087017
# Total embarked                                   1.000000           0.980226
# Total disembarked                                0.980226           1.000000
# Captive deaths during crossing                   0.627496           0.293227
# Duration of captives' crossing (in days)         0.208115           0.200321
# Crew at voyage outset                            0.210925           0.162157
#
#                                            Captive deaths during crossing  \
# Year of arrival at port of disembarkation                        0.101410
# Total embarked                                                   0.627496
# Total disembarked                                                0.293227
# Captive deaths during crossing                                   1.000000
# Duration of captives' crossing (in days)                         0.225274
# Crew at voyage outset                                            0.407579
#
#                                            Duration of captives' crossing (in days)  \
# Year of arrival at port of disembarkation                                  0.018499
# Total embarked                                                             0.208115
# Total disembarked                                                          0.200321
# Captive deaths during crossing                                             0.225274
# Duration of captives' crossing (in days)                                   1.000000
# Crew at voyage outset                                                     -0.061156
#
#                                            Crew at voyage outset
# Year of arrival at port of disembarkation              -0.126635
# Total embarked                                          0.210925
# Total disembarked                                       0.162157
# Captive deaths during crossing                          0.407579
# Duration of captives' crossing (in days)               -0.061156
# Crew at voyage outset                                   1.000000

# %%
## allerdings: keine wichtigen korrelationen...

# %%
# Stelle Korrelationen graphisch dar (seaborn)

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
sns.relplot(
    data=slaves,
    x="Duration of captives' crossing (in days)", y="Captive deaths during crossing"
)

# %%
p = sns.PairGrid(slaves)
p.map(sns.scatterplot)

# %%
# Gucke dir mean, variance etc an (statistische eigenschaften) für gewählte Kolumnen

# %%
## mean

# %%
print(slaves[["Total embarked", "Total disembarked"]].mean())
# Out:
# Total embarked       413.105747
# Total disembarked    367.942529
# dtype: float64

# %%
print(slaves["Captive deaths during crossing"].mean())
# Out:
# 62.38235294117647

# %%
## median

# %%
## varianz (-> streuung)

# %%
print(slaves["Total embarked"].var())
# Out:
# 29712.743695356003

# %%
print(slaves["Total disembarked"].var())
# Out:
# 22683.089903839795

# %%
print(slaves["Captive deaths during crossing"].var())
# Out:
# 6390.47494553377
